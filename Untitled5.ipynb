# %%
from os import listdir
from os.path import isfile, join
import numpy as np
import cv2
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt
# %matplotlib inline
#C:/Users/Shubham/Documents/Image_Processing/Dataset/Train/color/

# %%
mypath='C:/Users/Shubham/Documents/Image_Processing/Dataset/Train/color/'
onlyfiles = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]
images = np.empty(len(onlyfiles), dtype=object)
for n in range(0,len(onlyfiles)):
    images[n] = cv2.imread( join(mypath,onlyfiles[n]))
    r,c=images[n].shape[:2]
    out_r= 120
    images[n] = cv2.resize(images[n],(int(out_r*float(c)/r), out_r))
    images[n] = cv2.cvtColor(images[n], cv2.COLOR_BGR2RGB)

# %%
G,C = 0,0
km=KMeans(n_clusters=3)
for n in range(0,len(onlyfiles)):
    km.fit(images[n].reshape(-1,3))
    colors=np.asarray(km.cluster_centers_,dtype='uint8')
    per=np.asarray(np.unique(km.labels_,return_counts=True)[1],dtype='float32')
    per=per/(images[n].reshape(-1,3)).shape[0]
    dom=[[per[ix],colors[ix]] for ix in range(colors.shape[0])]
    Dom=sorted(dom, key =lambda z:z[0],reverse=True)
    start=0
    j,k = 0,0
    for i in range(km.n_clusters):
        print(Dom[i][1]) 
        if int(Dom[i][1][0]/3) == int(Dom[i][1][1]/3) == int(Dom[i][1][2]/3):
            j += 1 
        else:
            k += 1 
    if j > k:
        print('grey')
        plt.imshow(images[n])
        plt.pause(0.0001)
        G += 1
    if j < k:
        print ('color')
        plt.imshow(images[n])
        plt.pause(0.0001)
        C += 1
# Out:
# [254 254 254]
# [194 195 198]
# [66 77 91]
# color
# [254 253 251]
# [110 139  10]
# [228   4 228]
# color
# [253 253 253]
# [  2 162 158]
# [180  36  24]
# color
# [254 254 254]
# [168 170 173]
# [141  56  38]
# color
# [253 253 252]
# [190 205  83]
# [152 160  34]
# color
# [253 254 253]
# [171 171 169]
# [39 37 39]
# color
# [253 253 253]
# [29 29 30]
# [106 105 190]
# color
# [254 254 254]
# [207 207 212]
# [105 103 118]
# color
# [228 228 228]
# [253 253 253]
# [81 67 71]
# grey
# [254 254 254]
# [239 149  75]
# [8 8 8]
# grey
# [254 254 254]
# [71 71 71]
# [248  19  18]
# grey
# [254 254 254]
# [213 218 222]
# [128 137 145]
# color
# [253 253 253]
# [216 119  40]
# [ 82  99 114]
# color
# [4 4 4]
# [194 193 189]
# [ 97  98 103]
# color
# [254 254 254]
# [164 158 163]
# [53 42 51]
# color
# [254 254 254]
# [ 86 139 187]
# [202 203 204]
# color
# [254 254 254]
# [64 74 90]
# [186 199 208]
# color
# [254 254 254]
# [130 158 201]
# [31 28 31]
# color
# [254 254 252]
# [50 45 41]
# ...

# %%
z = len(onlyfiles)
Accuracy = max(G,C)/z
print(Accuracy * 100)
# Out:
# 73.63636363636363
